# %%
import pandas as pd
import numpy as np
import os
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# %%
print(os.getcwd())
# Out:
# /Users/angela/DSprojects

# %%
data = pd.read_csv('./DataExtract.csv', header=2)

# %%
data.head()
# Out:
#         pdc  num_ip_post  total_los_post  num_op_post  num_er_post  \
# 0  0.894444            0               0            8            0
# 1  0.333333            0               0            4            0
# 2  0.077778            0               0           32            0
# 3  0.333333            0               0           57            0
# 4  0.866667            0               0            5            0
#
#    num_ndc_post  num_gpi6_post  adjust_total_30d_post  generic_rate_post  \
# 0            17              3               6.966667           1.000000
# 1            15              5              14.466667           0.101382
# 2            11              7               3.833333           0.739130
# 3            16              6              24.000000           0.958333
# 4            16              4              18.000000           0.888889
#
#    post_ip_flag  ...   brand_cost  ratio_G_total_cost  numofgen_post  \
# ...

# %%
AD = data[data['drug_class'] == '*ANTIDIABETICS*']

# %%
patient_filter = AD[(AD['pdc_80_flag'] ==1) & (AD['brand_cost_post'] > 735)]

# %%
patient_filter
# Out:
#            pdc  num_ip_post  total_los_post  num_op_post  num_er_post  \
# 4     0.866667            0               0            5            0
# 21    0.977778            0               0            9            0
# 34    0.900000            0               0            7            0
# 38    0.966667            0               0            4            0
# 40    0.827778            0               0            0            0
# ...        ...          ...             ...          ...          ...
# 3489  0.961111            3              11           13            3
# 3494  0.888889            2              30           35            1
# 3506  0.966667            1               2           22            0
# 3509  0.900000            0               0            5            0
# 3522  0.900000            0               0           13            0
#
#       num_ndc_post  num_gpi6_post  adjust_total_30d_post  generic_rate_post  \
# ...

# %%
groupby = AD.groupby('pdc_80_flag')['generic_cost_post'].transform('median')

# %%
groupby
# Out:
# 1       109.730365
# 4       190.788893
# 5       109.730365
# 8       109.730365
# 16      190.788893
#            ...
# 3528    109.730365
# 3529    190.788893
# 3530    109.730365
# 3532    109.730365
# 3533    190.788893
# Name: generic_cost_post, Length: 1722, dtype: float64

# %%
numeric_cols = ['numofgen_post', 'numofbrand_post']
for col in numeric_cols:
    data[col] = data[col].fillna(data[col].median())
